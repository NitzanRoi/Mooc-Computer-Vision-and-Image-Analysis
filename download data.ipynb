# %%
## mount files:
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
import os, os.path
folder = 'Moocs/edx_Microsoft'
os.chdir('/content/drive/My Drive/'+folder)

# %%
# command to remove a package:
# !sudo apt-get remove youtube-dl

# command to download youtube-downloader package:
# !sudo curl -L https://yt-dl.org/downloads/latest/youtube-dl -o /usr/local/bin/youtube-dl
# !sudo chmod a+rx /usr/local/bin/youtube-dl

# # command to download one video:
# !youtube-dl https://www.youtube.com/watch?v=KgQzuRv-rmw

# install delegator:
# !pip3 install delegator.py

# code to download multiple videos:
# import delegator
# arr = ["https://youtu.be/IFKQLDmRK0Y", "https://youtu.be/okjYjClSjOg", "https://youtu.be/ecjN6Xpv6SE", "https://youtu.be/pYxNSUDSFH4",
#        "https://youtu.be/XepXtl9YKwc", "https://youtu.be/p3T-_LMrvBc", "https://youtu.be/4KKV9yZCoM4", "https://youtu.be/Dn6b9fCIUpM",
#        "https://youtu.be/ARfXDSkQf1Y", "https://youtu.be/8nm0G-1uJzA"]
# for i in arr:
#     cmd = 'youtube-dl ' + i
#     c = delegator.run(cmd, cwd='./', timeout=10)
# print('finish')

# download videos using axel:
# LINK ='http://host.robots.ox.ac.uk/pascal/VOC/voc2007/VOCtrainval_06-Nov-2007.tar' # train data
# LINK ='http://host.robots.ox.ac.uk/pascal/VOC/voc2007/VOCtest_06-Nov-2007.tar' # annotated test data
# ! sudo apt-get install axel
# ! axel -n 1 $LINK output='./data'

# extract tar files:
# !tar -xvf voc_test.tar

# !ls

# %cd test
# !ls train/VOC2007/Annotations

# get folder info:
# !du -h test
# !find train/VOC2007 -type d

# change folder name:
# !mv VOCdevkit test 

# print XML file:
# !sudo apt install libxml2-utils
# !ls train/VOC2007/Annotations
# !xmllint --format train/VOC2007/Annotations/008306.xml

# install ffmpeg:
# !sudo apt update
# !sudo apt install ffmpeg
# !ffmpeg -version

# extract all frames using ffmpeg:
# !ffmpeg -i my_video.mkv img%04d.jpg -hide_banner

# %%
# # move files to folder:
# # import glob
# # import shutil
# # images_folder = './images_messi'
# # for img in glob.glob('./*.jpg'):
# #     shutil.move(img, images_folder + img.split(".")[1])

# import cv2
# import numpy as np
# import matplotlib.pyplot as plt
# import math

# def show_two(arr_of_images, is_grayscale):
#     f = plt.figure(figsize=(30,30))
#     for i in range(len(arr_of_images)):
#         f.add_subplot(1,2,i+1)
#         if (is_grayscale):
#             plt.imshow(arr_of_images[i], cmap='gray', vmin=0, vmax=255)
#         else:
#             plt.imshow(arr_of_images[i])
#     plt.show(block=True)

# def show(img, is_grayscale):
#     plt.figure(figsize=(18,18))
#     if (is_grayscale):
#         plt.imshow(img, cmap='gray', vmin=0, vmax=255)
#     else:
#         plt.imshow(img)
#     plt.show()

# def to_grayscale(color_img):
#     return cv2.cvtColor(color_img, cv2.COLOR_BGR2GRAY)

# def read_img(path):
#     return cv2.imread(path, cv2.IMREAD_COLOR)

# def make_threshold(threshold_value, img):
#     return cv2.threshold(img, threshold_value, 255, cv2.THRESH_BINARY)[1]
#     # return cv2.threshold(img, threshold_value, 255, cv2.THRESH_BINARY_INV)[1]

# def make_gaussian_blur(img):
#     filter_size = (15,15) 
#     return cv2.GaussianBlur(img, filter_size, 0)

# def main():
#     folder = './images_messi'
#     img = '/img0001.jpg'
#     image = read_img(folder + img)
#     gray = to_grayscale(image)
#     thres = make_threshold(50, gray)
#     # show(make_gaussian_blur(image), False)
#     # show_two([gray, thres], True)

# main()

# %%
# TODO write python file to split the VOC db to categories according the XML annotations
# also untar the voc tar files (in voc folder)
